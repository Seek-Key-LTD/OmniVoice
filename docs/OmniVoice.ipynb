# %% [markdown]
# # OmniVoice — 一键启动
#
# 运行下面这个 cell，自动搞定：SSH + Gradio。

# %%
# !wget -q https://raw.githubusercontent.com/Seek-Key-LTD/OmniVoice/master/docs/bootstrap.py -O /tmp/bootstrap.py
# !python3 /tmp/bootstrap.py
